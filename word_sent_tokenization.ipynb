# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ----- ---------------------------------- 1.8/12.8 MB 8.9 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 7.3 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 7.0 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/12.8 MB 6.2 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 5.8 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 5.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 5.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 5.5 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 5.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 5.2 MB/s eta 0:00:01
# ...

# %%
nlp=spacy.load("en_core_web_sm")
doc=nlp("Dr.strange loves pabhaji of mumbai. Hulk loves chat")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr.strange loves pabhaji of mumbai.
# Hulk loves chat

# %%
nlp=spacy.load("en_core_web_sm")
doc=nlp("Dr.strange loves pabhaji of mumbai. Hulk loves chat")
for token in doc:
    print(token)
# Out:
# Dr.strange
# loves
# pabhaji
# of
# mumbai
# .
# Hulk
# loves
# chat

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize("Dr.strange loves pabhaji of mumbai. Hulk loves chat")
# Out:
# ['Dr.strange loves pabhaji of mumbai.', 'Hulk loves chat']

# %%
from nltk.tokenize import word_tokenize

word_tokenize("Dr.strange loves pabhaji of mumbai. Hulk loves chat")
# Out:
# ['Dr.strange',
#  'loves',
#  'pabhaji',
#  'of',
#  'mumbai',
#  '.',
#  'Hulk',
#  'loves',
#  'chat']
